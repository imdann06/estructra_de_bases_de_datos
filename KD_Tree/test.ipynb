# %% [markdown]
# <a href="https://colab.research.google.com/github/imdann06/estructra_de_bases_de_datos/blob/main/KD_Tree/test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Test
#
# En esta prueba se seleccionó un punto de consulta aleatorio dentro de un area de 500 metros. A partir de este punto, se realizó una búsqueda de todos los puntos de entrega ubicados dentro de un radio de 500 metros utilizando el árbol KD.
#
# El algoritmo identificó correctamente los puntos que se encuentran dentro del radio, devolviendo un total de 63 vecinos para este ejemplo. Además, se determinó el punto más cercano dentro de este conjunto.
#
# Lo que se imprime son los puntos dentro del radio de 500 metros

# %% [markdown]
# ![image.png](data:image/png;base64,...)![image.png](
#
# )

# %% [markdown]
# #COMPARACION DE TIEMPOS
#
#  se realizó 1000 mediciones del tiempo de ejecución para comparar el rendimiento del árbol KD frente a la búsqueda por fuerza bruta. El tiempo de consulta promedio utilizando el árbol KD fue de 0.000102 segundos, mientras que la fuerza bruta tardó 0.003286 segundos. Esto demuestra que el árbol KD es significativamente más eficiente

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Experimentos comparativos
#
# para que tamaño de datos el arbol-KD comienza a ser mas rapido que "fuerza bruta"
# (no arboles, si listas, ...)?
#
# Vemos que fuerza bruta solo supera al arbol KD en un tamaño de datos muy pequeños, en este caso solo 8.
#
# este fue el resultado general que obtuve, que a partir de 8 datos el arbol KD es mejor
#
#
# #EXPERIMENTO KD-TREE VS FUERZA BRUTA
#
#
# Tamaño de datos: 7
# Tiempo construcción KD-Tree: 0.000023 s
# Tiempo promedio consulta KD-Tree: 0.000003 s
# Tiempo promedio fuerza bruta: 0.000002 s
# ¿Resultados iguales en todas las consultas?: True
# Fuerza bruta fue más rápida en promedio
#
# Tamaño de datos: 8
# Tiempo construcción KD-Tree: 0.000017 s
# Tiempo promedio consulta KD-Tree: 0.000003 s
# Tiempo promedio fuerza bruta: 0.000002 s
# ¿Resultados iguales en todas las consultas?: True
# Fuerza bruta fue más rápida en promedio
#
# Tamaño de datos: 9
# Tiempo construcción KD-Tree: 0.000016 s
# Tiempo promedio consulta KD-Tree: 0.000003 s
# Tiempo promedio fuerza bruta: 0.000003 s
# ¿Resultados iguales en todas las consultas?: True
# KD-Tree fue más rápido en promedio
#
# Tamaño de datos: 10
# Tiempo construcción KD-Tree: 0.000018 s
# Tiempo promedio consulta KD-Tree: 0.000002 s
# Tiempo promedio fuerza bruta: 0.000005 s
# ¿Resultados iguales en todas las consultas?: True
# KD-Tree fue más rápido en promedio

# %% [markdown]
# Se verifico el algoritmo de forma visual para confirmar que este funcionara, en la figura se muestran todos los puntos de entrega distribuidos en el área de estudio, junto con el punto de consulta, el radio de búsqueda y los puntos encontrados dentro de dicho radio.
#
# El punto de consulta se representa en color azul, mientras que los puntos dentro del radio de 500 metros se muestran en rojo. Además, el punto más cercano se resalta con una estrella de color naranja. El círculo azul representa el área de búsqueda definida por el radio.

# %% [markdown]
# #VISUALIZACIÓN DE TODOS LOS PUNTOS Y EL RADIO DE CONSULTA
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Como se observa en la gráfica, todos los puntos marcados en rojo se encuentran dentro del círculo, lo que confirma que la búsqueda por radio funciona correctamente. Asimismo, el punto más cercano está claramente dentro del conjunto de vecinos, validando también la correcta identificación del vecino más cercano dentro del radio.
#
# Esta visualización permite comprobar que el algoritmo implementado es correcto

# %% [markdown]
# # analisis
#
# A partir de los experimentos realizados, se observa que el árbol KD presenta un mejor desempeño en el tiempo de consulta en comparación con la búsqueda por fuerza bruta, especialmente a medida que aumenta el tamaño del conjunto de datos.
#
# Sin embargo, el árbol KD introduce un costo adicional asociado a su construcción. En los casos donde se realiza una única consulta o el tamaño de datos es pequeño, la fuerza bruta puede ser mas rapida,
#
# A medida que el número de consultas aumenta,es mucho mejor el timpo del arbol KD que la fuerza bruta.
