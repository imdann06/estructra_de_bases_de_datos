# %% [markdown]
# <a href="https://colab.research.google.com/github/imdann06/estructra_de_bases_de_datos/blob/main/matriz%20100.000.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Crear una matriz de 100.000 x 100.000 y rellenarla de 0, 1, directamente en el disco duro

# %%
import numpy as np

filas= 100000
columnas= 100000

# matriz = np.random.randint(0, 2, size=(filas, columnas), dtype=bool)
# print(matriz)

#----- 10GB de RAM, toca mandarlos a disco directamente, y no llenamos la matriz con 0 y 1, sino con True y False, que ocupan menos espacio

# %%
import numpy as np

filas= 100000
columnas= 100000

with open("matrizz.bin", "wb") as f:
    for i in range(0, filas):
        bloque = np.random.randint(0, 2, size=(columnas), dtype=np.uint8)
        f.write(bloque.tobytes())


#codigo funcional, pero poco eficiente 75.4 segundos

# %%
#Mejora, se crea bloques de 1.000 asi que en lugar de 100.000 ciclos, hacemos 100 ciclos de 1,000 filas (107 segundos)
import numpy as np
filas = 100000
columnas = 100000
bloque_filas = 1000  # Escribimos de 1,000 en 1,000 para ir más rápido

with open("matriz.bin", "wb") as f:
    for i in range(0, filas, bloque_filas):
        bloque = np.random.randint(0, 2, size=(bloque_filas, columnas), dtype=np.uint8)
        f.write(bloque.tobytes())
